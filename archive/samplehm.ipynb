# %%
import json

with open(r"D:\Pics Can Lie\dataset\data\NewsClipPings\merged_balanced\train.json", "r") as f:
    data = json.load(f)

print(f"Total samples: {len(data)}")
# Out:
# Total samples: 2
